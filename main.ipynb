# %%
import pandas as pd
import numpy as np
from ydata_profiling import ProfileReport

# %%
feer_greed_data=pd.read_csv('fear_greed_index.csv')
historic_data=pd.read_csv('historical_data.csv')

# %%
# profile = ProfileReport(feer_greed_data, title="Fear and Greed Index Data Profiling Report")
# profile.to_file("fear_greed_data_profile.html")

# profile = ProfileReport(historic_data, title="Historical Data Profiling Report")
# profile.to_file("historical_data_profile.html")
